# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plot.scatter(x,y)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 5>()
#       3 x=[1,2,3,4,5]
#       4 y=[10,20,30,40,50]
# ----> 5 plot.scatter(x,y)
#       6 plot.show()
#
# NameError: name 'plot' is not defined

# %%
xpoints=np.array([1,2,3,8])
ypoints=np.array([3,4,6,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoinnts=np.array([3,5,6,1,6])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as pd
import numpy as np
ypoints=np.array([3,8,9,0,1,5])
plt.plot=(y points,marker='0'mec="r",color="pink",linewidth="200")
plt show()
# Out:
#   Input In [25]
#     plt.plot=(y points,marker='0'mec="r",color="pink",linewidth="200")
#                 ^
# SyntaxError: invalid syntax
