# %%
import matplotlib.pyplot as plt
n=Num.array[0.1,0.5,5.5]
plt.hist(num,bins=6,color="pink")
pltxlabel("NUMBERS")
pltylabel("FREQUENCY")
plt.title("NUMBERVSFREQUENCY")
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 n=Num.array[0.1,0.5,5.5]
#       3 plt.hist(num,bins=6,color="pink")
#       4 pltxlabel("NUMBERS")
#
# NameError: name 'Num' is not defined

# %%
import matplotlib.pyplot as np
x=[1,2,3,4,5]
y=[10,20,30,40,50,]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as np
x=[1,3,6,7,9]
y=[40,50,60,70,90]
plt.pie(x,y)
plt.show()
